# %%
from classifier_group import ClassifierGroup
from sklearn.svm import SVC
from data_funcs import DataManager
from sklearn.impute import KNNImputer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-6ec7531c7340> in <module>
# ----> 1 from classifier_group import ClassifierGroup
#       2 from sklearn.svm import SVC
#       3 from data_funcs import DataManager
#       4 from sklearn.impute import KNNImputer
#
# ~/detekcja/classifier_group.py in <module>
#       1 import itertools
# ----> 2 from classifier_wrapper import ClassifierWrapper
#       3 import pandas as pd
#       4 from data_funcs import DataManager
#       5 from name_utils import *
#
# ~/detekcja/classifier_wrapper.py in <module>
#       5 from os.path import abspath
#       6 from sklearn.metrics import RocCurveDisplay, ConfusionMatrixDisplay, accuracy_score, recall_score, precision_score
# ----> 7 from sklearn.model_selection import LearningCurveDisplay
#       8 from sklearn.preprocessing import LabelBinarizer
# ...

# %%
svcGL = ClassifierGroup([SVC], {"kernel": ["linear", "poly", "rbf", "sigmoid"], "C": [0.1, 1, 5, 8]}, {"probability": True, "break_ties": True},
                            dataManager=DataManager(imputation=KNNImputer(), standardize=None))

# %%
svcGL.calc_params()
# Out:
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
svcGL.plot_learning_curves()

# %%
svcGL.plot_rocs()

# %%
svcGL.plot_confusion_matrices()
